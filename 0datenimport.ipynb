# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # Alle Spalten anzeigen
# CSV mit Semikolon als Trenner einlesen
df = pd.read_csv("zhaw_export_arrivals.csv", sep=";")

# Erste Zeilen anzeigen (ohne print, dann kommt die schöne Tabelle!)
df.head(50)
# Out:
# C:\Users\janni\AppData\Local\Temp\ipykernel_31288\2515358714.py:4: DtypeWarning: Columns (3,4,14,15,16,17,18,25,26,27,28,29,33,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("zhaw_export_arrivals.csv", sep=";")
#    flight_identifier  flight_repeat_count scheduled_flight_date_utc  \
# 0              LX087                    0                01.01.2023
# 1             AC6820                    0                01.01.2023
# 2              LX139                    0                01.01.2023
# 3             CX6633                    0                01.01.2023
# 4             UA9731                    0                01.01.2023
# 5              LX243                    0                01.01.2023
# 6             AC6799                    0                01.01.2023
# 7              LX283                    0                01.01.2023
# 8             AC6817                    0                01.01.2023
# ...

# %%
# CSV mit Semikolon als Trenner einlesen
df = pd.read_csv("zhaw_export_departures.csv", sep=";")

# Erste Zeilen anzeigen (ohne print, dann kommt die schöne Tabelle!)
df.head(50)
# Out:
# C:\Users\janni\AppData\Local\Temp\ipykernel_31288\3294311192.py:2: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("zhaw_export_departures.csv", sep=";")
#    flight_identifier  flight_repeat_count scheduled_flight_date_utc  \
# 0             S48264                    0                01.01.2023
# 1             LX4590                    0                01.01.2023
# 2              TP933                    0                01.01.2023
# 3             AD7515                    0                01.01.2023
# 4              GM444                    0                01.01.2023
# 5              WK212                    0                01.01.2023
# 6             LX8212                    0                01.01.2023
# 7              WK200                    0                01.01.2023
# 8             LX8200                    0                01.01.2023
# ...
